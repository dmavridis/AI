# %% [markdown]
# ** Heuristic: ** Some additional piece of information -a rule, function or constant- that informs an otherwise brute-force algorithm to act in a more optimal manner
#
# ** Pruning the search tree **
#
# ** Adversarial search **
#
# ** Mini-Max Algorithm : ** You are trying to *maximize* your chances of winning on your turn, and your opponent is trying to minimize your chances of winning on their turn.
#
#
# ## Building blocks
# - Agent
# - Environment
# - Perception
# - Cognition
# - Action
#
#
# ## Types of problems
# - Fully vs Partially observable
# - Deterministic Vs Stohastic
# - Discrete Vs Continuous
# - Benign Vs Advarsarial
#
#
#
# An intelligent agent is one that takes actions to maximize its expected utility givena desired goal. Rational Behavior
#
# **Bounded Optimality**: Practical and feasible way of quantifying intelligence
#
# # Introduction to Game Playing
#
# Branching factor
#
# Nodes to visit: $$ b^d $$
#
# b: Branching Factor, d: Depth
#
# *Do the simple things first and only add intelligence when necessary* - Thad Starner
#
# **Depth Limited Search**
